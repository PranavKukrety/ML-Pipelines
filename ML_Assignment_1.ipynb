# %% [markdown]
# ## Data Exploration

# %%
import pandas as pd
import numpy as np

# %%
# load the dataset using pandas

# %%
df = pd.read_csv('/content/heart_disease_uci.csv')

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 915  st-t abnormality   154.0  False      0.0          NaN  NaN
# 916  st-t abnormality     NaN    NaN      NaN          NaN  NaN
# 917  st-t abnormality   100.0  False      0.0          NaN  NaN
# 918    lv hypertrophy     NaN    NaN      NaN          NaN  NaN
# 919    lv hypertrophy    93.0   True      0.0          NaN  NaN
#
#                   thal  num
# 0         fixed defect    0
# 1               normal    2
# 2    reversable defect    1
# 3               normal    0
# 4               normal    0
# ..                 ...  ...
# 915                NaN    1
# 916                NaN    0
# 917       fixed defect    2
# 918                NaN    0
# 919                NaN    1
#
# [920 rows x 16 columns]

# %%
##Display the first 5 rows and check for missing values and data types.

# %%
df.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# 2  lv hypertrophy   129.0   True      2.6         flat  2.0
# 3          normal   187.0  False      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0  False      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0

# %%
##Identify the types of features (categorical vs. numerical) and any possible missing data.

# %%
df.dtypes
# Out:
# id            int64
# age           int64
# sex          object
# dataset      object
# cp           object
# trestbps    float64
# chol        float64
# fbs          object
# restecg      object
# thalch      float64
# exang        object
# oldpeak     float64
# slope        object
# ca          float64
# thal         object
# num           int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %% [markdown]
# ## Handling Missing Data:

# %%
##Thal and Ca columns often have missing data. Impute missing values using the most
##frequent value for these categorical columns.

# %%
df['thal'].fillna(df['thal'].mode()[0], inplace=True)
df['ca'].fillna(df['ca'].mode()[0], inplace=True)
# Out:
# <ipython-input-10-35fd8ed38f73>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['thal'].fillna(df['thal'].mode()[0], inplace=True)
# <ipython-input-10-35fd8ed38f73>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ca'].fillna(df['ca'].mode()[0], inplace=True)

# %%
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 915  st-t abnormality   154.0  False      0.0          NaN  0.0
# 916  st-t abnormality     NaN    NaN      NaN          NaN  0.0
# 917  st-t abnormality   100.0  False      0.0          NaN  0.0
# 918    lv hypertrophy     NaN    NaN      NaN          NaN  0.0
# 919    lv hypertrophy    93.0   True      0.0          NaN  0.0
#
#                   thal  num
# 0         fixed defect    0
# 1               normal    2
# 2    reversable defect    1
# 3               normal    0
# 4               normal    0
# ..                 ...  ...
# 915             normal    1
# 916             normal    0
# 917       fixed defect    2
# 918             normal    0
# 919             normal    1
#
# [920 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca            0
# thal          0
# num           0
# dtype: int64

# %% [markdown]
# ##Feature Creation:

# %%
## Age Groups: Create age group categories (e.g., <40, 40-60, >60).

# %%
def age_group(age):
    if age<40:
        return ("<40")
    elif 40<= age <=60:
        return ("40-60")
    else:
        return (">60")

# %%
df["age_group"] = df["age"].apply(age_group)
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 915  st-t abnormality   154.0  False      0.0          NaN  0.0
# 916  st-t abnormality     NaN    NaN      NaN          NaN  0.0
# 917  st-t abnormality   100.0  False      0.0          NaN  0.0
# 918    lv hypertrophy     NaN    NaN      NaN          NaN  0.0
# 919    lv hypertrophy    93.0   True      0.0          NaN  0.0
#
#                   thal  num age_group
# 0         fixed defect    0       >60
# 1               normal    2       >60
# 2    reversable defect    1       >60
# 3               normal    0       <40
# 4               normal    0     40-60
# ..                 ...  ...       ...
# 915             normal    1     40-60
# 916             normal    0       >60
# 917       fixed defect    2     40-60
# 918             normal    0     40-60
# 919             normal    1       >60
#
# [920 rows x 17 columns]

# %%
## Cholesterol Level: Categorize the cholesterol levels into Low, Normal, and High.

# %%
def chol_types(chol):
    if chol < 200:
        return "Low"
    elif 200 <= chol <= 239:
        return "Medium"
    else:
        return "High"

# %%
df["chol_types"] = df["chol"].apply(chol_types)
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 915  st-t abnormality   154.0  False      0.0          NaN  0.0
# 916  st-t abnormality     NaN    NaN      NaN          NaN  0.0
# 917  st-t abnormality   100.0  False      0.0          NaN  0.0
# 918    lv hypertrophy     NaN    NaN      NaN          NaN  0.0
# 919    lv hypertrophy    93.0   True      0.0          NaN  0.0
#
#                   thal  num age_group chol_types
# 0         fixed defect    0       >60     Medium
# 1               normal    2       >60       High
# 2    reversable defect    1       >60     Medium
# 3               normal    0       <40       High
# 4               normal    0     40-60     Medium
# ..                 ...  ...       ...        ...
# 915             normal    1     40-60       High
# 916             normal    0       >60        Low
# 917       fixed defect    2     40-60     Medium
# 918             normal    0     40-60       High
# 919             normal    1       >60       High
#
# [920 rows x 18 columns]

# %%
## IsRisk: Create a binary feature that indicates high-risk patients based on criteria such
## as high cholesterol, high blood pressure, and age.

# %%
df['IsRisk'] = ((df['chol'] > 240) & (df['trestbps'] > 140) & (df['age'] > 60)).astype(int)
df
# Out:
#       id  age     sex        dataset               cp  trestbps   chol    fbs  \
# 0      1   63    Male      Cleveland   typical angina     145.0  233.0   True
# 1      2   67    Male      Cleveland     asymptomatic     160.0  286.0  False
# 2      3   67    Male      Cleveland     asymptomatic     120.0  229.0  False
# 3      4   37    Male      Cleveland      non-anginal     130.0  250.0  False
# 4      5   41  Female      Cleveland  atypical angina     130.0  204.0  False
# ..   ...  ...     ...            ...              ...       ...    ...    ...
# 915  916   54  Female  VA Long Beach     asymptomatic     127.0  333.0   True
# 916  917   62    Male  VA Long Beach   typical angina       NaN  139.0  False
# 917  918   55    Male  VA Long Beach     asymptomatic     122.0  223.0   True
# 918  919   58    Male  VA Long Beach     asymptomatic       NaN  385.0   True
# 919  920   62    Male  VA Long Beach  atypical angina     120.0  254.0  False
#
#               restecg  thalch  exang  oldpeak        slope   ca  \
# 0      lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1      lv hypertrophy   108.0   True      1.5         flat  3.0
# 2      lv hypertrophy   129.0   True      2.6         flat  2.0
# 3              normal   187.0  False      3.5  downsloping  0.0
# 4      lv hypertrophy   172.0  False      1.4    upsloping  0.0
# ..                ...     ...    ...      ...          ...  ...
# 915  st-t abnormality   154.0  False      0.0          NaN  0.0
# 916  st-t abnormality     NaN    NaN      NaN          NaN  0.0
# 917  st-t abnormality   100.0  False      0.0          NaN  0.0
# 918    lv hypertrophy     NaN    NaN      NaN          NaN  0.0
# 919    lv hypertrophy    93.0   True      0.0          NaN  0.0
#
#                   thal  num age_group chol_types  IsRisk
# 0         fixed defect    0       >60     Medium       0
# 1               normal    2       >60       High       1
# 2    reversable defect    1       >60     Medium       0
# 3               normal    0       <40       High       0
# 4               normal    0     40-60     Medium       0
# ..                 ...  ...       ...        ...     ...
# 915             normal    1     40-60       High       0
# 916             normal    0       >60        Low       0
# 917       fixed defect    2     40-60     Medium       0
# 918             normal    0     40-60       High       0
# 919             normal    1       >60       High       0
#
# [920 rows x 19 columns]

# %% [markdown]
# ## Feature Transformation

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
for column in ['sex','cp','thal','age_group']:
    df[column] = label_encoder.fit_transform(df[column])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
df[['chol','trestbps','thalch']] = scaler.fit_transform(df[['chol','trestbps','thalch']])

# %% [markdown]
# ### Feature Interaction

# %%
df['BP-Chol_Interaction'] = df['trestbps'] * df['chol']

# %%
df['Exercise_Angina_Risk'] = ((df['exang'] == 1) & (df['thalch'] < 100)).astype(int)

# %%
df.dtypes
# Out:
# id                        int64
# age                       int64
# sex                      object
# dataset                  object
# cp                       object
# trestbps                float64
# chol                    float64
# fbs                      object
# restecg                  object
# thalch                  float64
# exang                    object
# oldpeak                 float64
# slope                    object
# ca                      float64
# thal                     object
# num                       int64
# age_group                object
# chol_types               object
# IsRisk                    int64
# BP-Chol_Interaction     float64
# Exercise_Angina_Risk      int64
# dtype: object

# %% [markdown]
# ##Feature Selection:
